# %% [markdown]
# <a href="https://colab.research.google.com/github/harivign/Convering-JSON-file-to-Table-creation-using-python-/blob/main/Convert_JSON_file_to_Table_Creation_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #json to table

# %%
#for my practice I have convert json file to table creation using python

# %%
import json

# %%
auth={
  "apikey": "311dc6fc-1a0b-4280-8174-544203df4078",
  "id": "959aad88-d0b0-4f5d-8609-9fa25e50ba7b"
}

# %%
url="https://api.cricapi.com/v1/match_scorecard"

# %%
import requests

# %%
scorecard=requests.get(url,params=auth)
print(scorecard.json())
# Out:
# {'apikey': '311dc6fc-1a0b-4280-8174-544203df4078', 'data': {'id': '959aad88-d0b0-4f5d-8609-9fa25e50ba7b', 'name': 'South Africa vs India, 3rd T20I', 'matchType': 't20', 'status': 'India won by 11 runs', 'venue': 'SuperSport Park, Centurion', 'date': '2024-11-13', 'dateTimeGMT': '2024-11-13T15:00:00', 'teams': ['South Africa', 'India'], 'teamInfo': [{'name': 'India', 'shortname': 'IND', 'img': 'https://g.cricapi.com/iapi/31-637877061080567215.webp?w=48'}, {'name': 'South Africa', 'shortname': 'RSA', 'img': 'https://g.cricapi.com/iapi/82-637877071839088912.webp?w=48'}], 'score': [{'r': 219, 'w': 6, 'o': 20, 'inning': 'India Inning 1'}, {'r': 208, 'w': 7, 'o': 20, 'inning': 'South Africa Inning 1'}], 'tossWinner': 'South Africa', 'tossChoice': 'bowl', 'matchWinner': 'India', 'series_id': 'f27f88cc-096d-4130-83ec-437b26fd5f7b', 'scorecard': [{'batting': [{'batsman': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6', 'name': 'Sanju Samson'}, 'dismissal': 'bowled', 'bowler': {'id': 'd3c53885-7
# ...

# %%
import pprint

# %%
scorecard=requests.get(url,params=auth)
pprint.pprint(scorecard.json())
# Out:
# {'apikey': '311dc6fc-1a0b-4280-8174-544203df4078',
#  'data': {'date': '2024-11-13',
#           'dateTimeGMT': '2024-11-13T15:00:00',
#           'id': '959aad88-d0b0-4f5d-8609-9fa25e50ba7b',
#           'matchEnded': True,
#           'matchStarted': True,
#           'matchType': 't20',
#           'matchWinner': 'India',
#           'name': 'South Africa vs India, 3rd T20I',
#           'score': [{'inning': 'India Inning 1', 'o': 20, 'r': 219, 'w': 6},
#                     {'inning': 'South Africa Inning 1',
#                      'o': 20,
#                      'r': 208,
#                      'w': 7}],
#           'scorecard': [{'batting': [{'': 0,
#                                       '4s': 0,
#                                       '6s': 0,
#                                       'b': 2,
#                                       'batsman': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6',
#                                                   'name': 'Sanju Samson'},
# ...

# %%
import pandas as pd

# %%
indsa=scorecard.json()
df=pd.DataFrame(indsa)

# %%
from IPython.display import display
display(df)
# Out:
#                                             apikey  \
# id            311dc6fc-1a0b-4280-8174-544203df4078
# name          311dc6fc-1a0b-4280-8174-544203df4078
# matchType     311dc6fc-1a0b-4280-8174-544203df4078
# status        311dc6fc-1a0b-4280-8174-544203df4078
# venue         311dc6fc-1a0b-4280-8174-544203df4078
# date          311dc6fc-1a0b-4280-8174-544203df4078
# dateTimeGMT   311dc6fc-1a0b-4280-8174-544203df4078
# teams         311dc6fc-1a0b-4280-8174-544203df4078
# teamInfo      311dc6fc-1a0b-4280-8174-544203df4078
# score         311dc6fc-1a0b-4280-8174-544203df4078
# tossWinner    311dc6fc-1a0b-4280-8174-544203df4078
# tossChoice    311dc6fc-1a0b-4280-8174-544203df4078
# matchWinner   311dc6fc-1a0b-4280-8174-544203df4078
# series_id     311dc6fc-1a0b-4280-8174-544203df4078
# scorecard     311dc6fc-1a0b-4280-8174-544203df4078
# matchStarted  311dc6fc-1a0b-4280-8174-544203df4078
# matchEnded    311dc6fc-1a0b-4280-8174-544203df4078
# ...

# %%
df.to_csv("output.csv", index=False)

# %%
df = pd.json_normalize(indsa, sep="_")

print(df)
# Out:
#                                  apikey   status  \
# 0  311dc6fc-1a0b-4280-8174-544203df4078  success
#
#                                 data_id                        data_name  \
# 0  959aad88-d0b0-4f5d-8609-9fa25e50ba7b  South Africa vs India, 3rd T20I
#
#   data_matchType           data_status                  data_venue  \
# 0            t20  India won by 11 runs  SuperSport Park, Centurion
#
#     data_date     data_dateTimeGMT             data_teams  ...  \
# 0  2024-11-13  2024-11-13T15:00:00  [South Africa, India]  ...
#
#   data_matchStarted data_matchEnded info_hitsToday info_hitsUsed  \
# 0              True            True             20            10
#
#   info_hitsLimit info_credits info_server  info_queryTime  info_s  info_cache
# 0            100            0           8         16.0854       0           0
#
# [1 rows x 27 columns]

# %%
score1=pd.read_csv("/content/output.csv")

# %%
score1
# Out:
#                                   apikey  \
# 0   311dc6fc-1a0b-4280-8174-544203df4078
# 1   311dc6fc-1a0b-4280-8174-544203df4078
# 2   311dc6fc-1a0b-4280-8174-544203df4078
# 3   311dc6fc-1a0b-4280-8174-544203df4078
# 4   311dc6fc-1a0b-4280-8174-544203df4078
# 5   311dc6fc-1a0b-4280-8174-544203df4078
# 6   311dc6fc-1a0b-4280-8174-544203df4078
# 7   311dc6fc-1a0b-4280-8174-544203df4078
# 8   311dc6fc-1a0b-4280-8174-544203df4078
# 9   311dc6fc-1a0b-4280-8174-544203df4078
# 10  311dc6fc-1a0b-4280-8174-544203df4078
# 11  311dc6fc-1a0b-4280-8174-544203df4078
# 12  311dc6fc-1a0b-4280-8174-544203df4078
# 13  311dc6fc-1a0b-4280-8174-544203df4078
# 14  311dc6fc-1a0b-4280-8174-544203df4078
# 15  311dc6fc-1a0b-4280-8174-544203df4078
# 16  311dc6fc-1a0b-4280-8174-544203df4078
# 17  311dc6fc-1a0b-4280-8174-544203df4078
# 18  311dc6fc-1a0b-4280-8174-544203df4078
# 19  311dc6fc-1a0b-4280-8174-544203df4078
# 20  311dc6fc-1a0b-4280-8174-544203df4078
# 21  311dc6fc-1a0b-4280-8174-544203df4078
# ...

# %%
score1.iloc[14:15]
# Out:
#                                   apikey  \
# 14  311dc6fc-1a0b-4280-8174-544203df4078
#
#                                                  data   status  info
# 14  [{'batting': [{'batsman': {'id': '35ed1b20-38f...  success   NaN

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

# %%
data=score1.iloc[14:15]["data"]
data
# Out:
# 14    [{'batting': [{'batsman': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6', 'name': 'Sanju Samson'}, 'dismissal': 'bowled', 'bowler': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'dismissal-text': 'b marco jansen', 'r': 0, 'b': 2, '4s': 0, '6s': 0, 'sr': 0, '': 0}, {'batsman': {'id': '83fe6ab6-d63c-420e-9416-a93d59a9a964', 'name': 'Abhishek Sharma'}, 'dismissal': 'stumped', 'bowler': {'id': '97e9fec3-81bd-4018-a803-422c7d6d53aa', 'name': 'Keshav Maharaj'}, 'catcher': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'dismissal-text': 'st klaasen b maharaj', 'r': 50, 'b': 25, '4s': 3, '6s': 5, 'sr': 200, '': 0}, {'batsman': {'id': 'aefd9074-da5a-408d-94f1-3be0e79d3b82', 'name': 'Tilak Varma'}, 'dismissal-text': 'not out', 'r': 107, 'b': 56, '4s': 8, '6s': 7, 'sr': 191.07, '': 0}, {'batsman': {'id': '8c579447-bfbd-4cf6-a283-db4dc1d5ac33', 'name': 'Suryakumar Yadav'}, 'dismissal': 'catch', 'bowler': {'id': 'b127d731-849f-4afb-9265-
# ...

# %%
data = [{'batting': [{'batsman': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6', 'name': 'Sanju Samson'}, 'dismissal': 'bowled', 'bowler': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'dismissal-text': 'b marco jansen', 'r': 0, 'b': 2, '4s': 0, '6s': 0, 'sr': 0, '': 0}, {'batsman': {'id': '83fe6ab6-d63c-420e-9416-a93d59a9a964', 'name': 'Abhishek Sharma'}, 'dismissal': 'stumped', 'bowler': {'id': '97e9fec3-81bd-4018-a803-422c7d6d53aa', 'name': 'Keshav Maharaj'}, 'catcher': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'dismissal-text': 'st klaasen b maharaj', 'r': 50, 'b': 25, '4s': 3, '6s': 5, 'sr': 200, '': 0}, {'batsman': {'id': 'aefd9074-da5a-408d-94f1-3be0e79d3b82', 'name': 'Tilak Varma'}, 'dismissal-text': 'not out', 'r': 107, 'b': 56, '4s': 8, '6s': 7, 'sr': 191.07, '': 0}, {'batsman': {'id': '8c579447-bfbd-4cf6-a283-db4dc1d5ac33', 'name': 'Suryakumar Yadav'}, 'dismissal': 'catch', 'bowler': {'id': 'b127d731-849f-4afb-9265-5f66384666f7', 'name': 'Andile Simelane'}, 'catcher': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'dismissal-text': 'c marco jansen b simelane', 'r': 1, 'b': 4, '4s': 0, '6s': 0, 'sr': 25, '': 0}, {'batsman': {'id': 'a90b2371-5c53-4c29-a382-9b52d40a7548', 'name': 'Hardik Pandya'}, 'dismissal': 'lbw', 'bowler': {'id': '97e9fec3-81bd-4018-a803-422c7d6d53aa', 'name': 'Keshav Maharaj'}, 'dismissal-text': 'lbw b maharaj', 'r': 18, 'b': 16, '4s': 3, '6s': 0, 'sr': 112.5, '': 0}, {'batsman': {'id': '11864f31-b766-4766-9cbc-5026015ace48', 'name': 'Rinku Singh'}, 'dismissal': 'bowled', 'bowler': {'id': 'b127d731-849f-4afb-9265-5f66384666f7', 'name': 'Andile Simelane'}, 'dismissal-text': 'b simelane', 'r': 8, 'b': 13, '4s': 0, '6s': 0, 'sr': 61.54, '': 0}, {'batsman': {'id': '3187d301-269d-4823-b895-66d652ddefca', 'name': 'Ramandeep Singh '}, 'dismissal': 'runout', 'bowler': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'catcher': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'dismissal-text': 'run out', 'r': 15, 'b': 6, '4s': 1, '6s': 1, 'sr': 250, '': 0}, {'batsman': {'id': '670ae8ac-4fe9-4f0c-84ee-320b13039f34', 'name': 'Axar Patel'}, 'dismissal-text': 'not out', 'r': 1, 'b': 1, '4s': 0, '6s': 0, 'sr': 100, '': 0}], 'bowling': [{'bowler': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'o': 4, 'm': 0, 'r': 28, 'w': 1, 'nb': 1, 'wd': 2, 'eco': 7}, {'bowler': {'id': 'dd632169-52e3-4327-830e-dc5a9d18faa5', 'name': 'Gerald Coetzee'}, 'o': 3, 'm': 0, 'r': 51, 'w': 0, 'nb': 1, 'wd': 7, 'eco': 17}, {'bowler': {'id': '979c809d-86ea-47c1-b8f0-0f26e0a30056', 'name': 'Lutho Sipamla'}, 'o': 4, 'm': 0, 'r': 45, 'w': 0, 'nb': 1, 'wd': 1, 'eco': 11.2}, {'bowler': {'id': 'b127d731-849f-4afb-9265-5f66384666f7', 'name': 'Andile Simelane'}, 'o': 3, 'm': 0, 'r': 34, 'w': 2, 'nb': 0, 'wd': 0, 'eco': 11.3}, {'bowler': {'id': '3fef81b0-c1e9-45eb-954f-519f3b33d640', 'name': 'Aiden Markram'}, 'o': 2, 'm': 0, 'r': 19, 'w': 0, 'nb': 0, 'wd': 0, 'eco': 9.5}, {'bowler': {'id': '97e9fec3-81bd-4018-a803-422c7d6d53aa', 'name': 'Keshav Maharaj'}, 'o': 4, 'm': 0, 'r': 36, 'w': 2, 'nb': 0, 'wd': 0, 'eco': 9}], 'catching': [{'catcher': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'stumped': 1, 'runout': 0, 'catch': 0, 'cb': 0, 'lbw': 0, 'bowled': 0}, {'catcher': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'stumped': 0, 'runout': 0, 'catch': 1, 'cb': 0, 'lbw': 0, 'bowled': 1}, {'catcher': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'stumped': 0, 'runout': 1, 'catch': 0, 'cb': 0, 'lbw': 0, 'bowled': 0}, {'stumped': 0, 'runout': 0, 'catch': 0, 'cb': 0, 'lbw': 1, 'bowled': 0, 'catcher': {'id': '97e9fec3-81bd-4018-a803-422c7d6d53aa', 'name': 'Keshav Maharaj'}}, {'stumped': 0, 'runout': 0, 'catch': 0, 'cb': 0, 'lbw': 0, 'bowled': 1, 'catcher': {'id': 'b127d731-849f-4afb-9265-5f66384666f7', 'name': 'Andile Simelane'}}], 'extras': {'r': 19, 'b': 0}, 'totals': {}, 'inning': 'India Inning 1'}, {'batting': [{'batsman': {'id': 'a6686871-5bcd-4aae-8bfc-8298f878b6a9', 'name': 'Ryan Rickelton'}, 'dismissal': 'bowled', 'bowler': {'id': '607ff10c-5619-411d-a822-06ba28992230', 'name': 'Arshdeep Singh'}, 'dismissal-text': 'b arshdeep singh', 'r': 20, 'b': 15, '4s': 2, '6s': 1, 'sr': 133.33, '': 0}, {'batsman': {'id': '943c1332-8845-460b-93c9-3714d97f8788', 'name': 'Reeza Hendricks'}, 'dismissal': 'stumped', 'bowler': {'id': '702254aa-2764-4fe4-b28e-20336a0ab069', 'name': 'Varun Chakaravarthy'}, 'catcher': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6', 'name': 'Sanju Samson'}, 'dismissal-text': 'st samson b varun chakaravarthy', 'r': 21, 'b': 13, '4s': 4, '6s': 0, 'sr': 161.54, '': 0}, {'batsman': {'id': '3fef81b0-c1e9-45eb-954f-519f3b33d640', 'name': 'Aiden Markram'}, 'dismissal': 'catch', 'bowler': {'id': '702254aa-2764-4fe4-b28e-20336a0ab069', 'name': 'Varun Chakaravarthy'}, 'catcher': {'id': '3187d301-269d-4823-b895-66d652ddefca', 'name': 'Ramandeep Singh '}, 'dismissal-text': 'c ramandeep singh b varun chakaravarthy', 'r': 29, 'b': 18, '4s': 0, '6s': 2, 'sr': 161.11, '': 0}, {'batsman': {'id': 'de19a93e-06df-4597-9186-7a53c1613552', 'name': 'Tristan Stubbs'}, 'dismissal': 'lbw', 'bowler': {'id': '670ae8ac-4fe9-4f0c-84ee-320b13039f34', 'name': 'Axar Patel'}, 'dismissal-text': 'lbw b axar', 'r': 12, 'b': 12, '4s': 2, '6s': 0, 'sr': 100, '': 0}, {'batsman': {'id': '7d662361-8f12-4a52-9a4b-01e8734bd31d', 'name': 'Heinrich Klaasen'}, 'dismissal': 'catch', 'bowler': {'id': '607ff10c-5619-411d-a822-06ba28992230', 'name': 'Arshdeep Singh'}, 'catcher': {'id': 'aefd9074-da5a-408d-94f1-3be0e79d3b82', 'name': 'Tilak Varma'}, 'dismissal-text': 'c tilak varma b arshdeep singh', 'r': 41, 'b': 22, '4s': 1, '6s': 4, 'sr': 186.36, '': 0}, {'batsman': {'id': '2f50df2f-809d-44f9-b5be-ccb846515861', 'name': 'David Miller'}, 'dismissal': 'catch', 'bowler': {'id': 'a90b2371-5c53-4c29-a382-9b52d40a7548', 'name': 'Hardik Pandya'}, 'catcher': {'id': '670ae8ac-4fe9-4f0c-84ee-320b13039f34', 'name': 'Axar Patel'}, 'dismissal-text': 'c axar b hardik pandya', 'r': 18, 'b': 18, '4s': 1, '6s': 1, 'sr': 100, '': 0}, {'batsman': {'id': 'd3c53885-7016-4228-8a20-1dd98214489d', 'name': 'Marco Jansen'}, 'dismissal': 'lbw', 'bowler': {'id': '607ff10c-5619-411d-a822-06ba28992230', 'name': 'Arshdeep Singh'}, 'dismissal-text': 'lbw b arshdeep singh', 'r': 54, 'b': 17, '4s': 4, '6s': 5, 'sr': 317.65, '': 0}, {'batsman': {'id': 'dd632169-52e3-4327-830e-dc5a9d18faa5', 'name': 'Gerald Coetzee'}, 'dismissal-text': 'not out', 'r': 2, 'b': 3, '4s': 0, '6s': 0, 'sr': 66.67, '': 0}, {'batsman': {'id': 'b127d731-849f-4afb-9265-5f66384666f7', 'name': 'Andile Simelane'}, 'dismissal-text': 'not out', 'r': 5, 'b': 2, '4s': 1, '6s': 0, 'sr': 250, '': 0}], 'bowling': [{'bowler': {'id': '607ff10c-5619-411d-a822-06ba28992230', 'name': 'Arshdeep Singh'}, 'o': 4, 'm': 0, 'r': 37, 'w': 3, 'nb': 0, 'wd': 0, 'eco': 9.2}, {'bowler': {'id': 'a90b2371-5c53-4c29-a382-9b52d40a7548', 'name': 'Hardik Pandya'}, 'o': 4, 'm': 0, 'r': 50, 'w': 1, 'nb': 0, 'wd': 1, 'eco': 12.5}, {'bowler': {'id': '670ae8ac-4fe9-4f0c-84ee-320b13039f34', 'name': 'Axar Patel'}, 'o': 4, 'm': 0, 'r': 29, 'w': 1, 'nb': 0, 'wd': 0, 'eco': 7.2}, {'bowler': {'id': '702254aa-2764-4fe4-b28e-20336a0ab069', 'name': 'Varun Chakaravarthy'}, 'o': 4, 'm': 0, 'r': 54, 'w': 2, 'nb': 0, 'wd': 0, 'eco': 13.5}, {'bowler': {'id': '9a71201c-c377-45aa-a355-1af6d2c4bae3', 'name': 'Ravi Bishnoi'}, 'o': 4, 'm': 0, 'r': 33, 'w': 0, 'nb': 0, 'wd': 0, 'eco': 8.2}], 'catching': [{'catcher': {'id': '35ed1b20-38f3-4013-be2e-dc28ffbecfd6', 'name': 'Sanju Samson'}, 'stumped': 1, 'runout': 0, 'catch': 0, 'cb': 0, 'lbw': 0, 'bowled': 0}, {'catcher': {'id': '3187d301-269d-4823-b895-66d652ddefca', 'name': 'Ramandeep Singh '}, 'stumped': 0, 'runout': 0, 'catch': 1, 'cb': 0, 'lbw': 0, 'bowled': 0}, {'catcher': {'id': 'aefd9074-da5a-408d-94f1-3be0e79d3b82', 'name': 'Tilak Varma'}, 'stumped': 0, 'runout': 0, 'catch': 1, 'cb': 0, 'lbw': 0, 'bowled': 0}, {'catcher': {'id': '670ae8ac-4fe9-4f0c-84ee-320b13039f34', 'name': 'Axar Patel'}, 'stumped': 0, 'runout': 0, 'catch': 1, 'cb': 0, 'lbw': 1, 'bowled': 0}, {'stumped': 0, 'runout': 0, 'catch': 0, 'cb': 0, 'lbw': 1, 'bowled': 1, 'catcher': {'id': '607ff10c-5619-411d-a822-06ba28992230', 'name': 'Arshdeep Singh'}}], 'extras': {'r': 6, 'b': 0}, 'totals': {}, 'inning': 'South Africa Inning 1'}]

# Extract batting data
batting_data = []
for entry in data:
    for match in entry['batting']:
        batting_data.append({
            'Batsman': match['batsman']['name'],
            'Dismissal': match.get('dismissal', 'Not Out'),
            'Bowler': match.get('bowler', {}).get('name', ''),
            'Dismissal Text': match['dismissal-text'],
            'Runs': match['r'],
            'Balls': match['b'],
            '4s': match['4s'],
            '6s': match['6s'],
            'Strike Rate': match['sr']
        })

batting_df = pd.DataFrame(batting_data)

# Extract bowling data
bowling_data = []
for entry in data:
    for match in entry['bowling']:
        bowling_data.append({
            'Bowler': match['bowler']['name'],
            'Overs': match['o'],
            'Maidens': match['m'],
            'Runs Given': match['r'],
            'Wickets': match['w'],
            'No Balls': match['nb'],
            'Wide Balls': match['wd'],
            'Economy': match['eco']
        })

bowling_df = pd.DataFrame(bowling_data)

# Extract catching data
catching_data = []
for entry in data:
    for match in entry['catching']:
        catching_data.append({
            'Catcher': match['catcher']['name'],
            'Stumped': match['stumped'],
            'Run Out': match['runout'],
            'Catch': match['catch'],
            'Caught Behind': match['cb'],
            'LBW': match['lbw'],
            'Bowled': match['bowled']
        })

catching_df = pd.DataFrame(catching_data)

# Display DataFrames
print("Batting DataFrame:")
print(batting_df)

print("\nBowling DataFrame:")
print(bowling_df)

print("\nCatching DataFrame:")
print(catching_df)
# Out:
# Batting DataFrame:
#              Batsman Dismissal               Bowler  \
# 0       Sanju Samson    bowled         Marco Jansen
# 1    Abhishek Sharma   stumped       Keshav Maharaj
# 2        Tilak Varma   Not Out
# 3   Suryakumar Yadav     catch      Andile Simelane
# 4      Hardik Pandya       lbw       Keshav Maharaj
# 5        Rinku Singh    bowled      Andile Simelane
# 6   Ramandeep Singh     runout     Heinrich Klaasen
# 7         Axar Patel   Not Out
# 8     Ryan Rickelton    bowled       Arshdeep Singh
# 9    Reeza Hendricks   stumped  Varun Chakaravarthy
# 10     Aiden Markram     catch  Varun Chakaravarthy
# 11    Tristan Stubbs       lbw           Axar Patel
# 12  Heinrich Klaasen     catch       Arshdeep Singh
# 13      David Miller     catch        Hardik Pandya
# 14      Marco Jansen       lbw       Arshdeep Singh
# 15    Gerald Coetzee   Not Out
# 16   Andile Simelane   Not Out
#
#                              Dismissal Text  Runs  Balls  4s  6s  Strike Rate
# ...
